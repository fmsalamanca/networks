# %%
import numpy as np

# %%
data1 = np.loadtxt("connected_xlinksTEST2.txt",skiprows=1)-1
pos1 = np.loadtxt("crosslinks-positionsTEST2.txt",skiprows=1)

# %%
nxlink = len(data1)
indices = np.random.permutation(nxlink)  # from 0 to nxlink-1

# %%
print(max(indices), flush=True)
# Out:
# 80656

# %%
nxlink
# Out:
# 80657
