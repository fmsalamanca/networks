# %%
import numpy as np

# %%
data1 = np.loadtxt("connected_xlinksTEST1.txt",skiprows=1)

# %%
data2 = np.loadtxt("connected_xlinksTEST2.txt",skiprows=1)

# %%
len(data2)
# Out:
# 80657

# %%
len(data1)
# Out:
# 80657

# %%
pos1 = np.loadtxt("crosslinks-positionsTEST1.txt",skiprows=1)
pos2 = np.loadtxt("crosslinks-positionsTEST2.txt",skiprows=1)

# %%
pos1
# Out:
# array([[ -77.,   83.,  129.],
#        [ 145.,  -16.,  284.],
#        [   9.,  532.,  393.],
#        ...,
#        [ 228.,  458.,  593.],
#        [ 681., -259., -209.],
#        [  97.,  131., -116.]])

# %%
pos2
# Out:
# array([[ -77.,   83.,  129.],
#        [ 145.,  -16.,  284.],
#        [   9.,  532.,  393.],
#        ...,
#        [ 228.,  458.,  593.],
#        [ 681., -259., -209.],
#        [  97.,  131., -116.]])
